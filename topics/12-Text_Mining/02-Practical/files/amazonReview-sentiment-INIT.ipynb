# %% [markdown]
# # Sentiment Analysis of Amazon Reviews - INITialise Resources
#
# This notebook should be run once, to download the resources needed for this task.
# The resources are obtained from NLTK and include
# 1. VADER (Valence Aware Dictionary and sEntiment Reasoner) - Bag of words approach
# 2. Roberta Pretrained Model from 🤗

# %% [markdown]
# ## Step 0. Import NLTK
#
# Note that we also need to choose a lexicon of words for the bag of words model. Usually it is better to chooise a lexicon of words that are specific to the domain, but here we use a generic lexicon.

# %%
import nltk

# %% [markdown]
# ## Step 1. ownload the resources so they are available to NLTK.
#
# Depending on your internet connection, this can take time, so it just needs to be performed ONCE.

# %%
nltk.downloader.download('vader_lexicon')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
