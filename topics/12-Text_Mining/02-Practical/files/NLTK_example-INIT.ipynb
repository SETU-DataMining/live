# %% [markdown]
# # Introduction to NLTK - INITialisation
#
# This notebook is designed to be run ONCE, to download the necessary
# resources, before NLTK_example.ipynb is run for the first time.

# %%
import nltk

# %%
# The following downloads need to be performed just once.
#nltk.download()
nltk.download('punkt_tab')
nltk.download('tagsets_json')
nltk.download('omw-1.4')
